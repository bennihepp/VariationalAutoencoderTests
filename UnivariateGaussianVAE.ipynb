# %%
import itertools
import numpy as np
import torch
import torch.utils.data
from torch import nn
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
"""Overall initialization"""

seed = 41
torch.manual_seed(seed)

# Data types
dtype = torch.FloatTensor
np_dtype = np.float32

# PI and Gaussian PDF constants in Torch
pi_tensor = torch.Tensor([np.pi])
pi_variable = Variable(pi_tensor)
normal_log_likelihood_const = -torch.log(torch.sqrt(2 * pi_variable))

# Use gaussian likelihood or L2-norm for reconstruction loss?
use_likelihood = True

# Model parameters
hypersphere_n = 10
latent_size = 5
sigma_x = 0.05

# Training parameters
batch_size = 128
learning_rate = 1e-3

# Data parameters
num_samples = 100000
sigma = 0.05

# Hidden layer units in encoder and decoder (each entry is one layer)
enc_hidden_units_list = [512, 512]
dec_hidden_units_list = [512, 512]

# %%
"""Datasets"""

# Generate random data (Circle)
torch.manual_seed(seed)
rng = np.random.RandomState(seed)
u = 2 * np.pi * rng.rand(num_samples)[..., np.newaxis]
eps1 = sigma * rng.randn(num_samples)[..., np.newaxis]
eps2 = sigma * rng.randn(num_samples)[..., np.newaxis]
data = np.hstack([2 * np.cos(u) + eps1, np.sin(u) + eps2])
assert data.shape[0] == num_samples
num_features = data.shape[1]

# # Generate random data (Hypersphere)
# rng = np.random.RandomState(seed)
# u = rng.randn(num_samples, hypersphere_n)
# u /= np.sqrt(np.sum(u**2, axis=1))[:, np.newaxis]
# eps = sigma * rng.randn(num_samples, hypersphere_n)
# data = u + eps
# assert data.shape[0] == num_samples
# num_features = data.shape[1]

# # Generate random data (3 gaussians)
# torch.manual_seed(seed)
# rng = np.random.RandomState(seed)
# x1 = rng.multivariate_normal([1, 1], np.diag([0.1, 0.4]), size=num_samples // 2)
# x2 = rng.multivariate_normal([-1, -1], np.diag([0.1, 0.1]), size=num_samples // 4)
# x3 = rng.multivariate_normal([-1, 1], [[0.1, -0.3], [-0.3, 0.6]], size=num_samples // 4)
# data = np.vstack([x1, x2, x3])
# assert data.shape[0] == num_samples
# num_features = data.shape[1]

# Plot data
plt.clf()
plt.scatter(data[:, 0], data[:, 1], s=0.2)
plt.title("Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# Create a torch dataset (use zeros as dummy labels)
dataset = torch.utils.data.TensorDataset(torch.from_numpy(data), torch.zeros(num_samples))
kwargs = {}
train_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
"""Network model for encoder and decoder"""

class VAE(nn.Module):

    def __init__(self, input_size, latent_size, enc_hidden_units_list, dec_hidden_units_list):
        super(VAE, self).__init__()

        self.latent_size = latent_size

        # Encoder layers
        self.enc_fc_list = nn.ModuleList()
        prev_layer_size = input_size
        for i, num_hidden_units in enumerate(enc_hidden_units_list):
            fc = nn.Linear(prev_layer_size, num_hidden_units)
            self.enc_fc_list.append(fc)
            prev_layer_size = num_hidden_units
        self.enc_mu = nn.Linear(prev_layer_size, latent_size)
        self.enc_logvar = nn.Linear(prev_layer_size, latent_size)

        # Decoder layers
        self.dec_fc_list = nn.ModuleList()
        prev_layer_size = latent_size
        for i, num_hidden_units in enumerate(dec_hidden_units_list):
            fc = nn.Linear(prev_layer_size, num_hidden_units)
            self.dec_fc_list.append(fc)
            prev_layer_size = num_hidden_units
        self.dec_reconstruct = nn.Linear(prev_layer_size, input_size)

        # Activation functions
        self.relu = nn.ReLU()

    def encode(self, x):
        h = x
        for fc in self.enc_fc_list:
            h = fc(h)
            h = self.relu(h)
        mu = self.enc_mu(h)
        logvar = self.enc_logvar(h)
        return mu, logvar

    def decode(self, z):
        h = z
        for fc in self.dec_fc_list:
            h = fc(h)
            h = self.relu(h)
        return self.dec_reconstruct(h)

    def sample_latent_space(self, num_samples, dtype=torch.FloatTensor, volatile=False):
        z = Variable(torch.randn(num_samples, self.latent_size).type(dtype), volatile=volatile)
        return z

    def sample_latent_space_parametrized(self, mu, logvar):
        if self.training:
          sigma = logvar.mul(0.5).exp_()
          eps = Variable(sigma.data.new(sigma.size()).normal_())
          return eps.mul(sigma).add(mu)
        else:
          return mu

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.sample_latent_space_parametrized(mu, logvar)
        x_reconstruct = self.decode(z)
        return x_reconstruct, mu, logvar

model = VAE(num_features, latent_size, enc_hidden_units_list, dec_hidden_units_list)

# %%
"""Log likelihood and KL divergence"""

def pdf_normal(x, mu, sigma):
    sigma_sq = sigma * sigma
    norm_const = 1 / (np.sqrt(2 * np.pi) * sigma)
    p = torch.exp(-(x - mu) ** 2 / (2 * sigma_sq)) * norm_const
    return p

def log_pdf_normal(x, mu, sigma):
    sigma_sq = sigma * sigma
    log_norm_const = - torch.log(torch.sqrt(2 * pi_variable) * sigma)
    p = -(x - mu) ** 2 / (2 * sigma_sq) + log_norm_const
    return p

def log_pdf_normal_uncorrelated(x, mu, sigma):
    p = 0
    for i in range(mu.data.shape[-1]):
        p += log_pdf_normal(x[..., i], mu[..., i], sigma[..., i])
    return p

def log_pdf_normal_uncorrelated_logvar(x, mu, logvar):
    p = torch.sum(normal_log_likelihood_const - logvar.mul(0.5) - (x - mu).pow(2) / (2 * logvar.exp()), dim=-1)
    return p

def kl_divergence_normal_uncorrelated(mu1, sigma1, mu2, sigma2):
    kld = 0
    for i in range(mu1.data.shape[-1]):
        kld += kl_divergence_normal_univariate(mu1[..., i], sigma1[..., i], mu2[..., i], sigma2[..., i])
    return kld

def kl_divergence_normal_uncorrelated_identity(mu1, sigma1):
    kld = 0.5 * torch.sum(mu1.pow(2) + sigma1.pow(2) - 1 - torch.log(sigma1.pow(2)), dim=-1)
    return kld

def log_pdf_normal_uncorrelated_logvar(x, mu, logvar):
    p = torch.sum(normal_log_likelihood_const - logvar.mul(0.5) - (x - mu).pow(2) / (2 * logvar.exp()), dim=-1)
    return p

def kl_divergence_normal_uncorrelated_identity_logvar(mu1, logvar1):
    kld = 0.5 * torch.sum(mu1.pow(2) + logvar1.exp() - 1 - logvar1, dim=-1)
    return kld

# %%
"""Training"""

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

sigma_x_array = Variable(sigma_x * torch.ones(num_features))
logvar_x_array = torch.log(sigma_x_array.pow(2))

def loss_function(true_x, x, mu, logvar, return_loss_components=False):
    # Compute KL-divergence between `N(latent_mu, latent_sigma)` and unit normal distribution
    kld_q = kl_divergence_normal_uncorrelated_identity_logvar(mu, logvar)
    kld_q = torch.mean(kld_q)
    # Compute data loss
    if use_likelihood:
        log_likelihood_x = log_pdf_normal_uncorrelated_logvar(true_x, x, logvar_x_array)
        recon_loss = - torch.mean(log_likelihood_x)
    else:
        recon_loss = torch.mean((true_x - x).pow(2))
    # Total loss
    loss = recon_loss + kld_q
    if return_loss_components:
        return loss, recon_loss, kld_q
    else:
        return loss

model.train()

num_epochs = 100
for epoch in range(num_epochs):
    train_loss = 0
    train_recon_loss = 0
    train_kld = 0
    for i, (x, _) in enumerate(train_loader):
        x = Variable(x.type(dtype))

        optimizer.zero_grad()
        reconstruct_x, mu, logvar = model(x)
        loss, recon_loss, kld = loss_function(x, reconstruct_x, mu, logvar, return_loss_components=True)
        loss.backward()
        optimizer.step()

        train_loss += loss.data[0]
        train_recon_loss += recon_loss.data[0]
        train_kld += kld.data[0]
        if i % 1000 == 0:
            print("epoch={}, i={}".format(epoch, i))
            print("  loss: {:.4f}, recon_loss: {:.4f}, kld: {:.4f}".format(
                train_loss / (i + 1), train_recon_loss / (i + 1), train_kld / (i + 1)))
    train_loss *= batch_size / num_samples
    train_recon_loss *= batch_size / num_samples
    train_kld *= batch_size / num_samples
    print('====> Train set loss: {:.4f}, recon_loss: {:.4f}, kld: {:.4f}'.format(
        train_loss, train_recon_loss, train_kld))
# Out:
# epoch=0, i=0
#   loss: 471.7001, recon_loss: 471.6638, kld: 0.0364
# ====> Train set loss: 7.6158, recon_loss: 1.3431, kld: 6.2727
# epoch=1, i=0
#   loss: 2.7840, recon_loss: -2.6580, kld: 5.4419
# ====> Train set loss: 2.5300, recon_loss: -2.6528, kld: 5.1828
# epoch=2, i=0
#   loss: 2.5600, recon_loss: -2.5559, kld: 5.1159
# ====> Train set loss: 2.2562, recon_loss: -2.6131, kld: 4.8693
# epoch=3, i=0
#   loss: 2.2795, recon_loss: -2.4908, kld: 4.7703
# ====> Train set loss: 2.0799, recon_loss: -2.6297, kld: 4.7096
# epoch=4, i=0
#   loss: 2.5491, recon_loss: -2.2775, kld: 4.8266
# ====> Train set loss: 1.9942, recon_loss: -2.6788, kld: 4.6731
# epoch=5, i=0
#   loss: 2.0684, recon_loss: -2.5285, kld: 4.5969
# ====> Train set loss: 1.8176, recon_loss: -2.7868, kld: 4.6044
# epoch=6, i=0
#   loss: 1.9294, recon_loss: -2.9036, kld: 4.8330
# ====> Train set loss: 1.7867, recon_loss: -2.8435, kld: 4.6302
# epoch=7, i=0
#   loss: 1.7060, recon_loss: -2.9658, kld: 4.6718
# ====> Train set loss: 1.7446, recon_loss: -2.8662, kld: 4.6108
# epoch=8, i=0
#   loss: 1.4677, recon_loss: -3.0940, kld: 4.5617
# ====> Train set loss: 1.7115, recon_loss: -2.8953, kld: 4.6068
# epoch=9, i=0
#   loss: 1.7248, recon_loss: -2.8157, kld: 4.5405
# ====> Train set loss: 1.6451, recon_loss: -2.9573, kld: 4.6024
# epoch=10, i=0
#   loss: 1.2795, recon_loss: -3.1610, kld: 4.4404
# ====> Train set loss: 1.6550, recon_loss: -2.9535, kld: 4.6085
# epoch=11, i=0
#   loss: 1.8790, recon_loss: -2.7282, kld: 4.6071
# ====> Train set loss: 1.6137, recon_loss: -3.0069, kld: 4.6206
# epoch=12, i=0
#   loss: 1.2876, recon_loss: -3.1428, kld: 4.4304
# ====> Train set loss: 1.6151, recon_loss: -3.0148, kld: 4.6299
# epoch=13, i=0
#   loss: 1.6781, recon_loss: -2.7498, kld: 4.4280
# ====> Train set loss: 1.5784, recon_loss: -3.0241, kld: 4.6025
# epoch=14, i=0
#   loss: 1.6973, recon_loss: -2.8741, kld: 4.5714
# ====> Train set loss: 1.5533, recon_loss: -3.0260, kld: 4.5793
# epoch=15, i=0
#   loss: 1.4542, recon_loss: -3.2080, kld: 4.6622
# ====> Train set loss: 1.4989, recon_loss: -3.0674, kld: 4.5663
# epoch=16, i=0
#   loss: 1.4945, recon_loss: -2.9738, kld: 4.4683
# ====> Train set loss: 1.5657, recon_loss: -3.0391, kld: 4.6047
# epoch=17, i=0
#   loss: 1.2812, recon_loss: -2.9802, kld: 4.2615
# ====> Train set loss: 1.5006, recon_loss: -3.0744, kld: 4.5750
# epoch=18, i=0
#   loss: 2.6842, recon_loss: -2.1383, kld: 4.8225
# ====> Train set loss: 1.4971, recon_loss: -3.0909, kld: 4.5880
# epoch=19, i=0
#   loss: 1.2857, recon_loss: -3.0364, kld: 4.3221
# ====> Train set loss: 1.5096, recon_loss: -3.0766, kld: 4.5862
# epoch=20, i=0
#   loss: 1.3021, recon_loss: -3.2104, kld: 4.5124
# ====> Train set loss: 1.4988, recon_loss: -3.1298, kld: 4.6286
# epoch=21, i=0
#   loss: 1.3865, recon_loss: -3.0347, kld: 4.4212
# ====> Train set loss: 1.4409, recon_loss: -3.1378, kld: 4.5787
# epoch=22, i=0
#   loss: 1.1226, recon_loss: -3.1990, kld: 4.3215
# ====> Train set loss: 1.4330, recon_loss: -3.1291, kld: 4.5622
# epoch=23, i=0
#   loss: 1.2344, recon_loss: -3.3202, kld: 4.5545
# ====> Train set loss: 1.4712, recon_loss: -3.1399, kld: 4.6111
# epoch=24, i=0
#   loss: 1.3406, recon_loss: -3.1242, kld: 4.4648
# ====> Train set loss: 1.4267, recon_loss: -3.1255, kld: 4.5523
# epoch=25, i=0
#   loss: 1.6960, recon_loss: -2.9646, kld: 4.6607
# ====> Train set loss: 1.4397, recon_loss: -3.1373, kld: 4.5770
# epoch=26, i=0
#   loss: 1.5342, recon_loss: -3.3330, kld: 4.8671
# ====> Train set loss: 1.4273, recon_loss: -3.1475, kld: 4.5747
# epoch=27, i=0
#   loss: 1.5403, recon_loss: -2.9185, kld: 4.4588
# ====> Train set loss: 1.4665, recon_loss: -3.1446, kld: 4.6111
# epoch=28, i=0
#   loss: 1.8781, recon_loss: -2.9440, kld: 4.8221
# ====> Train set loss: 1.4925, recon_loss: -3.0916, kld: 4.5841
# epoch=29, i=0
#   loss: 1.2438, recon_loss: -3.1856, kld: 4.4294
# ====> Train set loss: 1.4725, recon_loss: -3.1428, kld: 4.6153
# epoch=30, i=0
#   loss: 2.5780, recon_loss: -1.7705, kld: 4.3485
# ====> Train set loss: 1.4043, recon_loss: -3.1623, kld: 4.5666
# epoch=31, i=0
#   loss: 1.3659, recon_loss: -3.3232, kld: 4.6890
# ====> Train set loss: 1.4066, recon_loss: -3.1531, kld: 4.5597
# epoch=32, i=0
#   loss: 1.2713, recon_loss: -3.3503, kld: 4.6216
# ====> Train set loss: 1.3810, recon_loss: -3.1763, kld: 4.5574
# epoch=33, i=0
#   loss: 1.6414, recon_loss: -2.8242, kld: 4.4655
# ====> Train set loss: 1.4114, recon_loss: -3.1563, kld: 4.5677
# epoch=34, i=0
#   loss: 1.2379, recon_loss: -3.3179, kld: 4.5558
# ====> Train set loss: 1.3688, recon_loss: -3.1594, kld: 4.5282
# epoch=35, i=0
#   loss: 1.3825, recon_loss: -3.0676, kld: 4.4500
# ====> Train set loss: 1.4113, recon_loss: -3.1533, kld: 4.5647
# epoch=36, i=0
#   loss: 1.2165, recon_loss: -3.3178, kld: 4.5343
# ====> Train set loss: 1.3882, recon_loss: -3.1817, kld: 4.5699
# epoch=37, i=0
#   loss: 1.1945, recon_loss: -3.2508, kld: 4.4453
# ====> Train set loss: 1.3925, recon_loss: -3.1666, kld: 4.5591
# epoch=38, i=0
#   loss: 1.2303, recon_loss: -3.1860, kld: 4.4163
# ====> Train set loss: 1.3597, recon_loss: -3.1871, kld: 4.5468
# epoch=39, i=0
#   loss: 1.3019, recon_loss: -3.2620, kld: 4.5639
# ====> Train set loss: 1.3705, recon_loss: -3.1617, kld: 4.5322
# epoch=40, i=0
#   loss: 1.3562, recon_loss: -3.0882, kld: 4.4444
# ====> Train set loss: 1.3595, recon_loss: -3.1752, kld: 4.5347
# epoch=41, i=0
#   loss: 1.1833, recon_loss: -3.3320, kld: 4.5154
# ====> Train set loss: 1.3730, recon_loss: -3.1815, kld: 4.5545
# epoch=42, i=0
#   loss: 1.2876, recon_loss: -3.3144, kld: 4.6020
# ====> Train set loss: 1.3943, recon_loss: -3.1847, kld: 4.5790
# epoch=43, i=0
#   loss: 1.1820, recon_loss: -3.3399, kld: 4.5220
# ====> Train set loss: 1.3734, recon_loss: -3.1787, kld: 4.5521
# epoch=44, i=0
#   loss: 1.3214, recon_loss: -3.2081, kld: 4.5295
# ====> Train set loss: 1.3385, recon_loss: -3.1795, kld: 4.5179
# epoch=45, i=0
#   loss: 1.3614, recon_loss: -3.1762, kld: 4.5376
# ====> Train set loss: 1.3766, recon_loss: -3.1701, kld: 4.5468
# epoch=46, i=0
#   loss: 1.3071, recon_loss: -3.1225, kld: 4.4297
# ====> Train set loss: 1.3703, recon_loss: -3.2077, kld: 4.5780
# epoch=47, i=0
#   loss: 1.3988, recon_loss: -3.3024, kld: 4.7012
# ====> Train set loss: 1.3707, recon_loss: -3.2212, kld: 4.5920
# epoch=48, i=0
#   loss: 1.3599, recon_loss: -3.1266, kld: 4.4865
# ====> Train set loss: 1.3281, recon_loss: -3.1967, kld: 4.5248
# epoch=49, i=0
#   loss: 1.2378, recon_loss: -3.2372, kld: 4.4750
# ====> Train set loss: 1.3534, recon_loss: -3.2203, kld: 4.5737
# epoch=50, i=0
#   loss: 1.2178, recon_loss: -3.2378, kld: 4.4556
# ====> Train set loss: 1.3503, recon_loss: -3.2097, kld: 4.5600
# epoch=51, i=0
#   loss: 1.2566, recon_loss: -3.2665, kld: 4.5231
# ====> Train set loss: 1.3444, recon_loss: -3.2208, kld: 4.5651
# epoch=52, i=0
#   loss: 1.2379, recon_loss: -3.2144, kld: 4.4523
# ====> Train set loss: 1.3632, recon_loss: -3.2030, kld: 4.5663
# epoch=53, i=0
#   loss: 1.1804, recon_loss: -3.3148, kld: 4.4952
# ====> Train set loss: 1.3699, recon_loss: -3.1905, kld: 4.5603
# epoch=54, i=0
#   loss: 1.4479, recon_loss: -3.0197, kld: 4.4676
# ====> Train set loss: 1.3419, recon_loss: -3.2060, kld: 4.5480
# epoch=55, i=0
#   loss: 1.3422, recon_loss: -3.4745, kld: 4.8167
# ====> Train set loss: 1.3381, recon_loss: -3.2104, kld: 4.5486
# epoch=56, i=0
#   loss: 1.3260, recon_loss: -3.4570, kld: 4.7830
# ====> Train set loss: 1.3334, recon_loss: -3.1972, kld: 4.5305
# epoch=57, i=0
#   loss: 1.5473, recon_loss: -3.2739, kld: 4.8211
# ====> Train set loss: 1.3735, recon_loss: -3.1860, kld: 4.5595
# epoch=58, i=0
#   loss: 1.1201, recon_loss: -3.3711, kld: 4.4913
# ====> Train set loss: 1.3707, recon_loss: -3.2210, kld: 4.5916
# epoch=59, i=0
#   loss: 1.2419, recon_loss: -3.3124, kld: 4.5543
# ====> Train set loss: 1.4700, recon_loss: -3.1996, kld: 4.6697
# epoch=60, i=0
#   loss: 1.3820, recon_loss: -3.2140, kld: 4.5960
# ====> Train set loss: 1.3926, recon_loss: -3.2117, kld: 4.6043
# epoch=61, i=0
#   loss: 1.3797, recon_loss: -3.1568, kld: 4.5365
# ====> Train set loss: 1.3560, recon_loss: -3.2341, kld: 4.5901
# epoch=62, i=0
#   loss: 1.1081, recon_loss: -3.4271, kld: 4.5352
# ====> Train set loss: 1.3430, recon_loss: -3.2096, kld: 4.5525
# epoch=63, i=0
#   loss: 1.4923, recon_loss: -3.3157, kld: 4.8080
# ====> Train set loss: 1.3400, recon_loss: -3.2248, kld: 4.5648
# epoch=64, i=0
#   loss: 1.4341, recon_loss: -3.2667, kld: 4.7009
# ====> Train set loss: 1.3126, recon_loss: -3.2314, kld: 4.5441
# epoch=65, i=0
#   loss: 1.2800, recon_loss: -3.1783, kld: 4.4584
# ====> Train set loss: 1.3484, recon_loss: -3.2103, kld: 4.5586
# epoch=66, i=0
#   loss: 1.3788, recon_loss: -3.2832, kld: 4.6620
# ====> Train set loss: 1.3405, recon_loss: -3.2270, kld: 4.5675
# epoch=67, i=0
#   loss: 1.4482, recon_loss: -3.1073, kld: 4.5556
# ====> Train set loss: 1.3838, recon_loss: -3.1895, kld: 4.5733
# epoch=68, i=0
#   loss: 1.3052, recon_loss: -3.2182, kld: 4.5234
# ====> Train set loss: 1.3154, recon_loss: -3.2150, kld: 4.5303
# epoch=69, i=0
#   loss: 1.5354, recon_loss: -3.1705, kld: 4.7059
# ====> Train set loss: 1.3332, recon_loss: -3.2228, kld: 4.5560
# epoch=70, i=0
#   loss: 1.4296, recon_loss: -3.4301, kld: 4.8597
# ====> Train set loss: 1.2996, recon_loss: -3.2333, kld: 4.5329
# epoch=71, i=0
#   loss: 1.5603, recon_loss: -2.8099, kld: 4.3702
# ====> Train set loss: 1.3805, recon_loss: -3.2169, kld: 4.5974
# epoch=72, i=0
#   loss: 1.4051, recon_loss: -3.2007, kld: 4.6058
# ====> Train set loss: 1.3275, recon_loss: -3.2232, kld: 4.5507
# epoch=73, i=0
#   loss: 1.2221, recon_loss: -3.2811, kld: 4.5032
# ====> Train set loss: 1.3362, recon_loss: -3.2387, kld: 4.5748
# epoch=74, i=0
#   loss: 1.0533, recon_loss: -3.3956, kld: 4.4489
# ====> Train set loss: 1.3027, recon_loss: -3.2412, kld: 4.5439
# epoch=75, i=0
#   loss: 1.3484, recon_loss: -3.1124, kld: 4.4608
# ====> Train set loss: 1.3309, recon_loss: -3.2236, kld: 4.5544
# epoch=76, i=0
#   loss: 1.2190, recon_loss: -3.3278, kld: 4.5468
# ====> Train set loss: 1.3273, recon_loss: -3.2079, kld: 4.5353
# epoch=77, i=0
#   loss: 1.0715, recon_loss: -3.4005, kld: 4.4720
# ====> Train set loss: 1.3162, recon_loss: -3.2385, kld: 4.5547
# epoch=78, i=0
#   loss: 1.0893, recon_loss: -3.4122, kld: 4.5015
# ====> Train set loss: 1.3417, recon_loss: -3.2477, kld: 4.5894
# epoch=79, i=0
#   loss: 1.2864, recon_loss: -3.2281, kld: 4.5145
# ====> Train set loss: 1.3663, recon_loss: -3.2226, kld: 4.5889
# epoch=80, i=0
#   loss: 1.3196, recon_loss: -3.2420, kld: 4.5616
# ====> Train set loss: 1.2782, recon_loss: -3.2160, kld: 4.4941
# epoch=81, i=0
#   loss: 1.3703, recon_loss: -2.9823, kld: 4.3526
# ====> Train set loss: 1.3196, recon_loss: -3.2305, kld: 4.5501
# epoch=82, i=0
#   loss: 1.1765, recon_loss: -3.4199, kld: 4.5964
# ====> Train set loss: 1.3285, recon_loss: -3.2257, kld: 4.5542
# epoch=83, i=0
#   loss: 1.1788, recon_loss: -3.2585, kld: 4.4373
# ====> Train set loss: 1.3302, recon_loss: -3.2518, kld: 4.5820
# epoch=84, i=0
#   loss: 1.2267, recon_loss: -3.2114, kld: 4.4381
# ====> Train set loss: 1.3220, recon_loss: -3.2269, kld: 4.5489
# epoch=85, i=0
#   loss: 1.4133, recon_loss: -3.1680, kld: 4.5813
# ====> Train set loss: 1.3143, recon_loss: -3.2105, kld: 4.5247
# epoch=86, i=0
#   loss: 1.4506, recon_loss: -3.3894, kld: 4.8400
# ====> Train set loss: 1.3046, recon_loss: -3.2397, kld: 4.5443
# epoch=87, i=0
#   loss: 1.1606, recon_loss: -3.2533, kld: 4.4140
# ====> Train set loss: 1.3086, recon_loss: -3.2430, kld: 4.5515
# epoch=88, i=0
#   loss: 1.3457, recon_loss: -3.1601, kld: 4.5059
# ====> Train set loss: 1.2923, recon_loss: -3.2460, kld: 4.5382
# epoch=89, i=0
#   loss: 1.4171, recon_loss: -3.2490, kld: 4.6661
# ====> Train set loss: 1.2984, recon_loss: -3.2177, kld: 4.5161
# epoch=90, i=0
#   loss: 1.5939, recon_loss: -2.9838, kld: 4.5777
# ====> Train set loss: 1.3323, recon_loss: -3.2532, kld: 4.5855
# epoch=91, i=0
#   loss: 1.2199, recon_loss: -3.2401, kld: 4.4600
# ====> Train set loss: 1.2987, recon_loss: -3.2438, kld: 4.5425
# epoch=92, i=0
#   loss: 1.4049, recon_loss: -3.2014, kld: 4.6063
# ====> Train set loss: 1.2857, recon_loss: -3.2385, kld: 4.5242
# epoch=93, i=0
#   loss: 1.4456, recon_loss: -3.1509, kld: 4.5965
# ====> Train set loss: 1.3390, recon_loss: -3.2500, kld: 4.5891
# epoch=94, i=0
#   loss: 1.3119, recon_loss: -3.1920, kld: 4.5039
# ====> Train set loss: 1.3471, recon_loss: -3.2462, kld: 4.5933
# epoch=95, i=0
#   loss: 1.2445, recon_loss: -3.3077, kld: 4.5522
# ====> Train set loss: 1.3127, recon_loss: -3.2238, kld: 4.5365
# epoch=96, i=0
#   loss: 1.1513, recon_loss: -3.2621, kld: 4.4134
# ====> Train set loss: 1.2835, recon_loss: -3.2193, kld: 4.5028
# epoch=97, i=0
#   loss: 1.3153, recon_loss: -3.2436, kld: 4.5589
# ====> Train set loss: 1.2774, recon_loss: -3.2364, kld: 4.5137
# epoch=98, i=0
#   loss: 1.4434, recon_loss: -3.3704, kld: 4.8138
# ====> Train set loss: 1.2745, recon_loss: -3.2416, kld: 4.5161
# epoch=99, i=0
#   loss: 1.3167, recon_loss: -3.2151, kld: 4.5318
# ====> Train set loss: 1.3119, recon_loss: -3.2365, kld: 4.5484

# %%
"""Plot decoded samples from latent space"""

num_samples_to_generate = 10000

model.eval()

# seed = 42
# rng = np.random.RandomState(seed)
# Sample latent vectors
z = model.sample_latent_space(num_samples_to_generate)
# z = Variable(torch.Tensor(rng.randn(num_samples_to_generate, latent_vec_size).astype(np_dtype)))
# Compute decoded value
x = model.decode(z)
x = x.data.numpy()
noise = sigma_x * rng.randn(num_samples_to_generate, num_features)
x += noise

# Plot data
plt.clf()
plt.scatter(data[:, 0], data[:, 1], s=1)
plt.scatter(x[:, 0], x[:, 1], s=.5)
plt.title("Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
"""Plot samples in latent space"""

model.eval()
latent_samples_mu = []
latent_samples_logvar = []
for i, (x, _) in enumerate(train_loader):
    x = Variable(x.type(dtype), volatile=True)
    recon_x, mu, logvar = model(x)
    latent_samples_mu.append(mu.data.numpy())
    latent_samples_logvar.append(logvar.data.numpy())
latent_samples_mu = np.concatenate(latent_samples_mu, axis=0)
latent_samples_logvar = np.concatenate(latent_samples_logvar, axis=0)

latent_dim1 = 0
latent_dim2 = 1
x = latent_samples_mu[..., latent_dim1].ravel()
y = latent_samples_mu[..., latent_dim2].ravel()
# Generate samples from target latent distribution, i.e. N(0, I)
target_x, target_y = np.random.randn(len(x)), np.random.randn(len(x))

plt.figure()
plt.scatter(target_x, target_y, s=0.5)
plt.scatter(x, y, s=0.5)
plt.title("Samples in latent space")
plt.xlabel("Latent dim {:d}".format(latent_dim1))
plt.xlabel("Latent dim {:d}".format(latent_dim2))
plt.legend(["Target distribution", "Train set"])
plt.show()
plt.close()

plt.figure()
plt.hist2d(x, y, 20)
plt.title("Distribution of train samples in latent space")
plt.xlabel("Latent dim {:d}".format(latent_dim1))
plt.xlabel("Latent dim {:d}".format(latent_dim2))
plt.show()
plt.close()

plt.figure()
plt.hist2d(target_x, target_y, 20)
plt.title("Target distribution for latent space")
plt.show()
plt.close()

# %%
"""Interpolate between data points"""

model.eval()
for i in range(10):
    # seed = 46
    # rng = np.random.RandomState(seed)
    idx1, idx2 = rng.choice(np.arange(num_samples), size=2, replace=False)
    print(idx1, idx2)
    x1, mu1, sigma1 = model(Variable(torch.Tensor(data[idx1, :]).type(dtype), volatile=True))
    x2, mu2, sigma2 = model(Variable(torch.Tensor(data[idx2, :]).type(dtype), volatile=True))
    w = Variable(torch.linspace(0, 1, 1000))
    z = mu1 + (mu2 - mu1) * w[:, None]
    x = model.decode(z)

    x1 = x1.data.numpy()
    x2 = x2.data.numpy()
    x = x.data.numpy()

    plt.figure()
    plt.scatter(data[:, 0], data[:, 1], s=0.001)
    plt.plot(data[[idx1, idx2], 0], data[[idx1, idx2], 1], 'x')
    plt.plot([x1[0], x2[0]], [x1[1], x2[1]], 'o')
    plt.plot(x[:, 0], x[:, 1], '.')
    plt.xlim([-1, 1])
    plt.ylim([-1, 1])
    plt.show()
# Out:
#   File "<ipython-input-106-95ce55d3c50c>", line 1
#     Interpolate between data points
#                       ^
# SyntaxError: invalid syntax
